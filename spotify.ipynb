# %%
import math
import statistics
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/home/zenolucas/Desktop/SCHOOLING/dataAnalytics/TS_spotify.csv')
df
# Out:
#      Unnamed: 0                                               name  \
# 0             0                                      Lavender Haze
# 1             1                                             Maroon
# 2             2                                          Anti-Hero
# 3             3             Snow On The Beach (feat. Lana Del Rey)
# 4             4                            You're On Your Own, Kid
# ..          ...                                                ...
# 753        1246  Mary's Song (Oh My My My) - Instrumental w/ BG...
# 754        1247               Our Song - Instrumental w/ BG vocals
# 755        1248  I'm Only Me When I'm With You - Instrumental w...
# 756        1249              Invisible - Instrumental w/ BG vocals
# 757        1250  A Perfectly Good Heart - Instrumental w/ BG vo...
#
#                               album release_date  track_number  \
# 0           Midnights (3am Edition)   2022-10-22             1
# ...

# %%
mean = df.groupby("album").agg({"popularity" : "mean"})
mean
# Out:
#                                                     popularity
# album
# 1989                                                 31.357143
# 1989 (Big Machine Radio Release Special)             30.884615
# 1989 (Deluxe Edition)                                59.157895
# Fearless                                             17.000000
# Fearless (Big Machine Radio Release Special)         34.961538
# Fearless (International Version)                     36.062500
# Fearless (Karaoke Version)                            6.615385
# Fearless (Platinum Edition)                          47.210526
# Fearless (Taylor's Version)                          65.961538
# Live From Clear Channel Stripped 2008                34.000000
# Lover                                                75.166667
# Midnights                                            85.769231
# Midnights (3am Edition)                              82.150000
# Red                                                  47.500000
# ...
